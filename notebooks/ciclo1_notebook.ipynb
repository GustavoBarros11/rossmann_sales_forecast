# %% [markdown]
# # 0.0) Import das Bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
import inflection
import warnings
import requests
import random
import pickle
import json
import math
import re
import os

from boruta import BorutaPy
from scipy import stats as ss
from tabulate import tabulate
from IPython.display import Image
from datetime import datetime, timedelta
from matplotlib.gridspec import GridSpec

from sklearn.preprocessing import MinMaxScaler, RobustScaler, LabelEncoder, OrdinalEncoder, OneHotEncoder
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.ensemble import RandomForestRegressor

warnings.filterwarnings('ignore')

# %% [markdown]
# ### 0.1) Funções Auxiliares

# %%
def mean_percentage_error( y, yhat ):
    return np.mean( ( y - yhat ) / y )

def mean_absolute_percentage_error( y, yhat ):
    return np.mean( np.abs( ( y - yhat ) / y ) )

def ml_error(label, y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    mape = mean_absolute_percentage_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))

    return pd.DataFrame({'Model Name': label, 'MAE': mae, 'MAPE': mape, 'RMSE': rmse}, index=[0])

def plot_2_var_corr(df, col1, col2):
    x = sns.heatmap( df[[col1, col2]].corr( method='pearson' ), cmap='mako', annot=True );
    #bottom, top = x.get_ylim()
    #x.set_ylim( bottom+0.5, top-0.5 );
    
    return x

def cramer_v( x, y ):
    cm = pd.crosstab( x, y ).values
    n = cm.sum()
    r, k = cm.shape
    chi2 = ss.chi2_contingency( cm )[0]
    chi2corr = max( 0, chi2 - (k-1)*(r-1)/(n-1) )
    kcorr = k - (k-1)**2/(n-1)
    rcorr = r - (r-1)**2/(n-1)

    return np.sqrt( (chi2corr/n) / ( min( kcorr-1, rcorr-1 ) ) )

def cross_validation( x_training, kfold, model_name, model, verbose=False ):
    mae_list = []
    mape_list = []
    rmse_list = []
    for k in reversed( range( 1, kfold+1 ) ):
        if verbose:
            print( '\nKFold Number: {}'.format( k ) )
        # start and end date for validation 
        validation_start_date = x_training['date'].max() - datetime.timedelta( days=k*6*7)
        validation_end_date = x_training['date'].max() - datetime.timedelta( days=(k-1)*6*7)

        # filtering dataset
        training = x_training[x_training['date'] < validation_start_date]
        validation = x_training[(x_training['date'] >= validation_start_date) & (x_training['date'] <= validation_end_date)]

        # training and validation dataset
        # training
        xtraining = training.drop( ['date', 'sales'], axis=1 ) 
        ytraining = training['sales']

        # validation
        xvalidation = validation.drop( ['date', 'sales'], axis=1 )
        yvalidation = validation['sales']

        # model
        m = model.fit( xtraining, ytraining )

        # prediction
        yhat = m.predict( xvalidation )

        # performance
        m_result = ml_error( model_name, np.expm1( yvalidation ), np.expm1( yhat ) )

        # store performance of each kfold iteration
        mae_list.append(  m_result['MAE'] )
        mape_list.append( m_result['MAPE'] )
        rmse_list.append( m_result['RMSE'] )

    return pd.DataFrame({'Model Name': model_name,
                          'MAE CV': np.round( np.mean( mae_list ), 2 ).astype( str ) + ' +/- ' + np.round( np.std( mae_list ), 2 ).astype( str ),
                          'MAPE CV': np.round( np.mean( mape_list ), 2 ).astype( str ) + ' +/- ' + np.round( np.std( mape_list ), 2 ).astype( str ),
                          'RMSE CV': np.round( np.mean( rmse_list ), 2 ).astype( str ) + ' +/- ' + np.round( np.std( rmse_list ), 2 ).astype( str ) }, index=[0])

def jupyter_settings():
    # %matplotlib inline

    plt.rcParams['figure.figsize'] = (24, 12)
    plt.rcParams['font.size'] = 24
    pd.set_option('display.float_format', '{:.2f}'.format)
    pd.set_option('display.max_columns', 100)

    sns.set_theme()

# %%
jupyter_settings()

# %% [markdown]
# ### 0.2) Coleta dos Dados

# %%
df_train = pd.read_csv('../data/train.csv')
df_store = pd.read_csv('../data/store.csv')

df_raw = df_train.merge(df_store, how='left', on='Store')

# %% [markdown]
# # 1.0) Descrição dos Dados

# %%
df1 = df_raw.copy()
df1.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0              1         c          a              1270.00
# 1              1         a          a               570.00
# 2              1         a          a             14130.00
# 3              1         c          c               620.00
# 4              1         a          a             29910.00
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                       9.00                   2008.00       0
# ...

# %% [markdown]
# ### 1.1) Renomear colunas

# %% [markdown]
# Renomear as colunas para um formato padrão e mais legível.

# %%
for col in df1.columns:
    print(col, end=' | ')
# Out:
# Store | DayOfWeek | Date | Sales | Customers | Open | Promo | StateHoliday | SchoolHoliday | StoreType | Assortment | CompetitionDistance | CompetitionOpenSinceMonth | CompetitionOpenSinceYear | Promo2 | Promo2SinceWeek | Promo2SinceYear | PromoInterval |

# %%
# rename columns 
snakecase = lambda x: inflection.underscore( x )

df1.columns = list( map( snakecase, df1.columns.values ) )

# %% [markdown]
# ### 1.2) Dimensão dos Dados

# %%
print(f'Total de linhas: {df1.shape[0]:,}')
print(f'Total de colunas: {df1.shape[1]}')
# Out:
# Total de linhas: 1,017,209
# Total de colunas: 18

# %% [markdown]
# ### 1.3) Tipos dos Dados

# %%
df1['date'] = pd.to_datetime( df1['date'] )
df1.dtypes
# Out:
# store                                    int64
# day_of_week                              int64
# date                            datetime64[ns]
# sales                                    int64
# customers                                int64
# open                                     int64
# promo                                    int64
# state_holiday                           object
# school_holiday                           int64
# store_type                              object
# assortment                              object
# competition_distance                   float64
# competition_open_since_month           float64
# competition_open_since_year            float64
# promo2                                   int64
# promo2_since_week                      float64
# promo2_since_year                      float64
# promo_interval                          object
# dtype: object

# %% [markdown]
# ### 1.4) Valores NAs

# %% [markdown]
# Existem diversas colunas com valores nulos, neste primeiro ciclo, irei imputá-los com zero apenas.

# %%
df1.isna().sum()
# Out:
# store                                0
# day_of_week                          0
# date                                 0
# sales                                0
# customers                            0
# open                                 0
# promo                                0
# state_holiday                        0
# school_holiday                       0
# store_type                           0
# assortment                           0
# competition_distance              2642
# competition_open_since_month    323348
# competition_open_since_year     323348
# promo2                               0
# promo2_since_week               508031
# promo2_since_year               508031
# promo_interval                  508031
# dtype: int64

# %% [markdown]
# ### 1.5) Tratando valores NAs

# %%
df1.sample()
# Out:
#        store  day_of_week       date  sales  customers  open  promo  \
# 63093    654            5 2015-06-05   7930        741     1      1
#
#       state_holiday  school_holiday store_type assortment  \
# 63093             0               0          c          a
#
#        competition_distance  competition_open_since_month  \
# 63093               6930.00                          9.00
#
#        competition_open_since_year  promo2  promo2_since_week  \
# 63093                      2006.00       0                NaN
#
#        promo2_since_year promo_interval
# 63093                NaN            NaN

# %%
# competition_distance
df1['competition_distance'].fillna(0, inplace=True)

# promo_interval
df1['promo_interval'].fillna(0, inplace=True)

# competition_open_since_month
df1['competition_open_since_month'] = df1.apply(lambda x: x['date'].month if math.isnan(x['competition_open_since_month']) else x['competition_open_since_month'], axis=1)

# competition_open_since_year
df1['competition_open_since_year'] = df1.apply(lambda x: x['date'].year if math.isnan(x['competition_open_since_year']) else x['competition_open_since_year'], axis=1)

# promo2_since_week
df1['promo2_since_week'] = df1.apply(lambda x: x['date'].weekofyear if math.isnan(x['promo2_since_week']) else x['promo2_since_week'], axis=1)

# promo2_since_year
df1['promo2_since_year'] = df1.apply(lambda x: x['date'].year if math.isnan(x['promo2_since_year']) else x['promo2_since_year'], axis=1)

# state_holiday
df1['state_holiday'] = df1['state_holiday'].map(lambda x: '0' if x == 0 else x)

# %%
df1.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# Agora que não possuímos mais valores nulos em nosso dataframe, podemos então prosseguir com os próximos passos.

# %% [markdown]
# ### 1.6) Corrigindo Tipos dos Dados

# %% [markdown]
# Aqui estão algumas transformações nos tipos dos dados para auxiliar posteriormente na criação de gráficos, na descrição estatística e por serem mais convenientes que os anteriores.

# %%
# competition_open_since_year -> int
df1['competition_open_since_year'] = df1['competition_open_since_year'].astype(int)

# competition_open_since_month -> int
df1['competition_open_since_month'] = df1['competition_open_since_month'].astype(int)

# promo2_since_year -> int
df1['promo2_since_year'] = df1['promo2_since_year'].astype(int)

# promo2_since_week -> int
df1['promo2_since_week'] = df1['promo2_since_week'].astype(int)

# %% [markdown]
# ### 1.7) Estatísticas de Resumo

# %%
num_attr, cat_attr = df1.select_dtypes(include=['int', 'float']), df1.select_dtypes(exclude=['int', 'float'])

# %% [markdown]
# **Variáveis Numéricas**

# %%
num_stats = pd.concat([num_attr.describe().T.drop(columns=['count']), \
    pd.DataFrame({'skew': num_attr.skew(), 'kurtosis': num_attr.kurtosis()})], axis=1)
num_stats
# Out:
#                                 mean     std     min     25%     50%     75%  \
# store                         558.43  321.91    1.00  280.00  558.00  838.00
# day_of_week                     4.00    2.00    1.00    2.00    4.00    6.00
# sales                        5773.82 3849.93    0.00 3727.00 5744.00 7856.00
# customers                     633.15  464.41    0.00  405.00  609.00  837.00
# open                            0.83    0.38    0.00    1.00    1.00    1.00
# promo                           0.38    0.49    0.00    0.00    0.00    1.00
# school_holiday                  0.18    0.38    0.00    0.00    0.00    0.00
# competition_distance         5415.98 7710.25    0.00  700.00 2320.00 6880.00
# competition_open_since_month    6.79    3.31    1.00    4.00    7.00   10.00
# competition_open_since_year  2010.32    5.52 1900.00 2008.00 2012.00 2014.00
# promo2                          0.50    0.50    0.00    0.00    1.00    1.00
# ...

# %%
sns.distplot(df1['competition_distance'])

plt.show()

# %% [markdown]
# **Variáveis Categóricas**

# %%
cat_stats = pd.concat([cat_attr.describe().T.drop(columns=['count']), \
    pd.DataFrame({'skew': cat_attr.skew(), 'kurtosis': cat_attr.kurtosis()})], axis=1)
cat_stats
# Out:
#                unique                  top      freq      first       last  \
# date              942  2015-07-31 00:00:00      1115 2013-01-01 2015-07-31
# state_holiday       4                    0    986159        NaT        NaT
# store_type          4                    a    551627        NaT        NaT
# assortment          3                    a    537445        NaT        NaT
# promo_interval   4.00                 0.00 508031.00        NaT        NaT
#
#                 skew  kurtosis
# date             NaN       NaN
# state_holiday    NaN       NaN
# store_type       NaN       NaN
# assortment       NaN       NaN
# promo_interval   NaN       NaN

# %%
aux1 = df1[(df1['sales'] > 0) & (df1['state_holiday'] != '0')]

fig, ax = plt.subplots(1, 3)

# state_holiday
sns.boxplot(data=aux1, x='state_holiday', y='sales', ax=ax[0])

# store_type
sns.boxplot(data=aux1, x='store_type', y='sales', ax=ax[1])

# assortment
sns.boxplot(data=aux1, x='assortment', y='sales', ax=ax[2])

plt.show()

# %% [markdown]
# # 2.0) Feature Engineering

# %%
df2 = df1.copy()

# %% [markdown]
# ### 2.1) Mindmap de Hipóteses

# %%
Image('../img/DAILY_STORE_SALES.png')

# %% [markdown]
# ### 2.2) Criação das Hipóteses

# %% [markdown]
# #### 2.2.1. Hipoteses Loja
# 1. Lojas com número maior de funcionários deveriam vender mais.
# 2. Lojas com maior capacidade de estoque deveriam vender mais.
# 3. Lojas com maior porte deveriam vender mais.
# 4. Lojas com maior sortimentos deveriam vender mais.
# 5. Lojas com competidores mais próximos deveriam vender menos.
# 6. Lojas com competidores à mais tempo deveriam vendem mais.
#
# #### 2.2.2. Hipoteses Produto
# 1. Lojas que investem mais em Marketing deveriam vender mais.
# 2. Lojas com maior exposição de produto deveriam vender mais.
# 3. Lojas com produtos com preço menor deveriam vender mais.
# 5. Lojas com promoções mais agressivas ( descontos maiores ), deveriam vender mais.
# 6. Lojas com promoções ativas por mais tempo deveriam vender mais.
# 7. Lojas com mais dias de promoção deveriam vender mais.
# 8. Lojas com mais promoções consecutivas deveriam vender mais.
#
# #### 2.2.3. Hipoteses Tempo
# 1. Lojas abertas durante o feriado de Natal deveriam vender mais.
# 2. Lojas deveriam vender mais ao longo dos anos.
# 3. Lojas deveriam vender mais no segundo semestre do ano.
# 4. Lojas deveriam vender mais depois do dia 10 de cada mês.
# 5. Lojas deveriam vender menos aos finais de semana.
# 6. Lojas deveriam vender menos durante os feriados escolares.

# %% [markdown]
# ### 2.3) Lista Final de Hipóteses

# %% [markdown]
# 1. Lojas com maior variedade de produtos, em média, deveriam vender mais.
# 2. Lojas com competidores mais próximos deveriam vender menos.
# 3. Lojas com competidores à mais tempo deveriam vendem mais.
# 4. Lojas com promoções ativas por mais tempo deveriam vender mais.
# 5. Lojas com mais dias de promoção deveriam vender mais.
# 6. Lojas com mais promoções consecutivas deveriam vender mais.
# 7. Lojas abertas durante o feriado de Natal deveriam vender mais.
# 8. Lojas deveriam vender mais ao longo dos anos.
# 9. Lojas deveriam vender mais no segundo semestre do ano.
# 10. Lojas deveriam vender mais depois do dia 10 de cada mês.
# 11. Lojas deveriam vender menos aos finais de semana.
# 12. Lojas deveriam vender menos durante os feriados escolares.

# %% [markdown]
# ### 2.4) Feature Engineering

# %%
# day
df2['day'] = df2['date'].dt.day

# month
df2['month'] = df2['date'].dt.month

# year
df2['year'] = df2['date'].dt.year

# week_of_year
df2['week_of_year'] = df2['date'].dt.weekofyear

# year_week
df2['year_week'] = df2['date'].dt.strftime('%Y-%W')

# assortment
assortment_map = {'a': 'basic', 'b': 'extra', 'c': 'extended'}
df2['assortment'] = df2['assortment'].map(assortment_map)

# state_holiday
state_holiday_map = { 'a': 'public_holiday', 'b': 'easter_holiday', 'c': 'christmas', '0': 'regular_day'}
df2['state_holiday'] = df2['state_holiday'].map(state_holiday_map)

# competition_open_since
df2['competition_open_since'] = df2.apply(lambda x: datetime(year=x['competition_open_since_year'] if x['competition_open_since_year'] != 0 else x['date'].year, \
    month=x['competition_open_since_month'] if x['competition_open_since_month'] != 0 else x['date'].month, day=1), axis=1)

# competition_duration
df2['competition_duration'] = df2.apply(lambda x: np.round((x['date'] - x['competition_open_since']).days / 30).astype(int), axis=1)

# promo2_since
df2['promo2_since'] = df2.apply(lambda x: f"{x['promo2_since_year']}-{x['promo2_since_week']}" if  x['promo2_since_year'] != 0 else x['date'].strftime('%Y-%W'), axis=1)

df2['promo2_since'] = df2['promo2_since'].apply( lambda x: datetime.strptime( x + '-1', '%Y-%W-%w' ) - timedelta( days=7 ) )

df2['promo_time_week'] = ( ( df2['date'] - df2['promo2_since'] ) / 7 ).apply(lambda x: x.days ).astype( int )

# promo_interval
month_map = {1: 'Jan', 2: 'Fev', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun', 7: 'Jul', \
    8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'}

df2['month_map'] = df2['month'].map( month_map )
df2['is_promo'] = df2[['promo_interval', 'month_map']].apply( lambda x: 0 if x['promo_interval'] == 0 else 1 \
    if x['month_map'] in x['promo_interval'].split( ',' ) else 0, axis=1 ).astype('bool')
df2.loc[(df2['promo_time_week'] == 0) & (df2['is_promo'] == 1), 'promo_time_week'] = 1

# %%
df2.head().T
# Out:
#                                                 0                    1  \
# store                                           1                    2
# day_of_week                                     5                    5
# date                          2015-07-31 00:00:00  2015-07-31 00:00:00
# sales                                        5263                 6064
# customers                                     555                  625
# open                                            1                    1
# promo                                           1                    1
# state_holiday                         regular_day          regular_day
# school_holiday                                  1                    1
# store_type                                      c                    a
# assortment                                  basic                basic
# competition_distance                      1270.00               570.00
# ...

# %%
df2.dtypes
# Out:
# store                                    int64
# day_of_week                              int64
# date                            datetime64[ns]
# sales                                    int64
# customers                                int64
# open                                     int64
# promo                                    int64
# state_holiday                           object
# school_holiday                           int64
# store_type                              object
# assortment                              object
# competition_distance                   float64
# competition_open_since_month             int64
# competition_open_since_year              int64
# promo2                                   int64
# promo2_since_week                        int64
# promo2_since_year                        int64
# promo_interval                          object
# day                                      int64
# month                                    int64
# ...

# %% [markdown]
# # 3.0) Filtragem de Variáveis

# %%
df3 = df2.copy()

# %% [markdown]
# ### 3.1) Filtragem das Linhas

# %%
df3 = df3.query('open != 0 & sales > 0')

# %% [markdown]
# ### 3.2) Seleção das Colunas

# %%
cols_drop = ['customers', 'open', 'promo_interval', 'month_map']
#cols_drop_2 = ['customers', 'open', 'competition_open_since_month',
#       'competition_open_since_year', 'promo2_since_week',
#       'promo2_since_year', 'promo_interval', 'month_map']

df3.drop(columns=cols_drop, inplace=True)

# %% [markdown]
# # 4.0) Análise Exploratória de Dados

# %%
df4 = df3.copy()

# %% [markdown]
# ### 4.1) Análise Univariada

# %% [markdown]
# #### 4.1.2) Variável Target

# %%
sns.distplot(df4['sales']);

# %% [markdown]
# #### 4.1.2) Variáveis Numéricas

# %%
num_attr = df4.select_dtypes(include=[int, float, 'datetime64[ns]'])
num_attr.hist(bins=25);

# %% [markdown]
# #### 4.1.3) Variáveis Categóricas

# %%
df4['state_holiday'].unique()
# Out:
# array(['regular_day', 'public_holiday', 'easter_holiday', 'christmas'],
#       dtype=object)

# %%
# state_holiday
plt.subplot( 4, 2, 1 )
sns.countplot( data=df4[df4['state_holiday'] != 'regular_day'], x='state_holiday' )

plt.subplot( 4, 2, 2 )
sns.kdeplot( df4[df4['state_holiday'] == 'public_holiday']['sales'], label='public_holiday', fill=True )
sns.kdeplot( df4[df4['state_holiday'] == 'easter_holiday']['sales'], label='easter_holiday', fill=True )
sns.kdeplot( df4[df4['state_holiday'] == 'christmas']['sales'], label='christmas', fill=True )

# store_type
plt.subplot( 4, 2, 3 )
sns.countplot( data=df4, x='store_type' )

plt.subplot( 4, 2, 4 )
sns.kdeplot( df4[df4['store_type'] == 'a']['sales'], label='a', fill=True )
sns.kdeplot( df4[df4['store_type'] == 'b']['sales'], label='b', fill=True )
sns.kdeplot( df4[df4['store_type'] == 'c']['sales'], label='c', fill=True )
sns.kdeplot( df4[df4['store_type'] == 'd']['sales'], label='d', fill=True )

# assortment
plt.subplot( 4, 2, 5 )
sns.countplot( data=df4, x='assortment' )

plt.subplot( 4, 2, 6 )
sns.kdeplot( df4[df4['assortment'] == 'extended']['sales'], label='extended', fill=True )
sns.kdeplot( df4[df4['assortment'] == 'basic']['sales'], label='basic', fill=True )
sns.kdeplot( df4[df4['assortment'] == 'extra']['sales'], label='extra', fill=True )

# is_promo
plt.subplot( 4, 2, 7)
sns.countplot(data=df4, x='is_promo')

plt.subplot( 4, 2, 8)
sns.kdeplot(data=df4, x='sales', hue='is_promo', fill=True)
plt.title('is_promo', fontsize=12)

plt.show()

# %% [markdown]
# ### 4.2) Análise Bivariada

# %% [markdown]
# #### **H1.** Lojas com maior variedade de produtos, em média, deveriam vender mais.
# **VERDADEIRO** Nota-se um acréscimo médio nas vendas de 14.32% por nível de assortment.

# %%
df_h1 = df4.groupby('assortment').agg({'sales': 'mean'}).reset_index()
# Calculate the average percentage variation between two consecutive values of assortment
df_h1['AoA'] = df_h1['sales'].rolling(window=2)\
    .apply( lambda x: round((x.iloc[1] / x.iloc[0] -1) * 100,2) )\
        .drop(index=0).reset_index(drop=True)
df_h2 = df4.groupby('assortment').agg({'sales': 'count'}).reset_index()
df_h1_2 = df4.groupby(['year_week', 'assortment']).agg({'sales': 'mean'}).reset_index()

# bar chart
plt.subplot(1, 2, 1)

ax = sns.barplot(data=df_h1, x='assortment', y='sales', palette='mako')
ax.set_title('Mean Sales per Assortment', fontsize = 25)
# incluindo labels nas barras
for i in ax.containers:
    ax.bar_label(i, color='white', label_type= 'center', fontsize=20, fmt='%.2f')

# donut chart
# Create a pie plot
plt.subplot(1, 2, 2)

# plt.pie(df_h2['sales'], labels=df_h2['assortment'])
wedges, texts, autotexts = plt.pie( data = df_h2,
                                   x = 'sales',
                                   autopct = lambda x: str(round(float(x),1)) + "%",
                                   textprops = dict(color="w"))
plt.legend( wedges, list(df_h2['assortment']),
          title = "Assortments",
          loc="center left",
          bbox_to_anchor = (1, 0, 0.5, 1))
plt.setp(autotexts, size=20, weight="bold")
plt.title("Count of Assortments",fontsize = 25);

fig, ax2 = plt.subplots()

df_h1_2.pivot( index='year_week', columns='assortment', values='sales' ).plot(ax=ax2)
ax2.set_title('Average sales over time per assortment', fontsize=25)

plt.show()

# %%
print(f"Assortment over assortment (AoA): {df_h1['AoA'].mean():.2f}%")
# Out:
# Assortment over assortment (AoA): 14.32%

# %% [markdown]
# #### H2. Lojas com competidores mais próximos deveriam vender menos, na média.
# **FALSO** Não nota-se variação significativa no volume médio de vendas a depender da distância para competidores, nem para mais nem para menos.

# %%
df_h2 = df4[['competition_distance','sales']].groupby('competition_distance').mean().reset_index()
bins = list(np.arange(0,20000,1000))
df_h2['competitions_distance_bined'] = pd.cut(df_h2['competition_distance'],bins=bins)
df_h2_1 = df_h2[['competitions_distance_bined','sales']].groupby('competitions_distance_bined').mean().reset_index()

# %%
plt.subplot()

ax = sns.barplot(data=df_h2_1, x='competitions_distance_bined', y='sales', palette='mako')
# adding bar's labels
for i in ax.containers:
    ax.bar_label(i, color='black', label_type= 'edge',fontsize=20,fmt='%.0f',rotation=0)

ax.set_xticklabels(df_h2_1['competitions_distance_bined'], rotation=90)
ax.set_title('Mean sales per Competition Distance', fontsize=25)

fig, ax = plt.subplots(1, 2)

sns.scatterplot(data=df_h2, x='competition_distance', y='sales', ax=ax[0])
ax[0].set_title('Sales per Competition Distance', fontsize=25)

x = sns.heatmap( df_h2[['competition_distance', 'sales']].corr( method='pearson' ), cmap='mako', annot=True );
bottom, top = x.get_ylim()
x.set_ylim( bottom+0.5, top-0.5 );
x.set_title("Correlation of sales and competition_distance", fontsize=25)

plt.show()

# %% [markdown]
# #### H3. Lojas com competidores à mais tempo deveriam vender mais.
# **FALSO** Lojas com competidores a mais tempo tendem a vender menos. Na verdade, nota-se que o pico de vendas é logo anterior a abertura da loja competidora, depois o volume continua alto por algum período de tempo após a abertura da competição e no longo praso o volume de vendas médio tende a voltar para os níveis iniciais.

# %%
df_h3 = df4.loc[(df4['competition_duration'] < 120) & (df4['competition_duration'] != 0),\
     ['competition_duration','sales']].groupby('competition_duration').mean().reset_index()

plt.subplot()

sns.barplot( x = 'competition_duration', y = 'sales', data = df_h3, palette = 'mako');
plt.title( 'Mean Sales per Competition Duration (months)', fontsize = 25 )
plt.xticks( rotation = 90 )
plt.ylim( bottom = 6000 )

fig, ax = plt.subplots(1, 2)

sns.scatterplot(data=df_h3, x='competition_duration', y='sales', ax=ax[0])
ax[0].set_title('Sales per Competition Duration', fontsize=25)

ax[1] = plot_2_var_corr(df4, 'competition_duration', 'sales')
ax[1].set_title("Correlation of sales and competition_distance", fontsize=25)

plt.show()

# %% [markdown]
# #### H4. Lojas com promoções ativas por mais tempo deveriam vender mais.
# **VERDADEIRO** Lojas com promocoes ativas por mais tempo, tendem a vender mais, na média. Esse comportamento parece ser constante ao longo de todo o período estudado.

# %%
df_h4 = df4[['promo_time_week', 'sales']].groupby('promo_time_week').mean().reset_index()

grid = GridSpec( 2, 3 )

plt.subplot( grid[0,0] )
df_h4_2 = df_h4[df_h4['promo_time_week'] > 0].rolling(4).mean() # promo extendido
sns.lineplot( x='promo_time_week', y='sales', data=df_h4_2 );

plt.title('Mean sales by promotion duration (in weeks)', fontsize=20)
plt.xticks( rotation=90 );

plt.subplot( grid[0,1] )
sns.regplot( x='promo_time_week', y='sales', data=df_h4_2 );
plt.title('Tendecy of sales per promo_time_week', fontsize=20)

plt.subplot( grid[1,0] )
df_h4_3 = df_h4[df_h4['promo_time_week'] < 0].rolling(4).mean() # promo regular
sns.lineplot( x='promo_time_week', y='sales', data=df_h4_3 );
plt.xticks( rotation=90 );

plt.subplot( grid[1,1] )
sns.regplot( x='promo_time_week', y='sales', data=df_h4_3 );

plt.subplot( grid[:,2] )
sns.heatmap( df_h4.corr( method='pearson' ), cmap='mako', annot=True );
plt.title('Correlation of sales and promo_time_week', fontsize=20)

plt.show()

# %% [markdown]
# #### <s>**H5.** Lojas com mais dias de promoção deveriam vender mais.</s>

# %% [markdown]
# #### H6. Lojas com mais promoções consecutivas deveriam vender mais.
# **FALSO** Lojas em períodos de promoção Tradicional & Extendida, na média, vendem menos que Lojas em período Tradicional de promoção.

# %%
df_h6_1 = df4.query("promo == 1 & promo2 == 1").groupby('year_week').agg({'sales': 'mean'})
df_h6_2 = df4.query("promo == 1 & promo2 == 0").groupby('year_week').agg({'sales': 'mean'})

fig, ax = plt.subplots()

sns.lineplot(data=df_h6_1, x='year_week', y='sales', label='Tradicional & Extendida', ax=ax)
sns.lineplot(data=df_h6_2, x='year_week', y='sales', label='Tradicional', ax=ax)
plt.xticks(rotation=90)

ax.set_title('Traditional vs Extended promotions average sales over time', fontsize=25)

plt.legend()
plt.show()

# %% [markdown]
# #### H7. Lojas abertas durante o feriado de Natal deveriam vender mais.
# **VERDADEIRO** Lojas abertas no período de Natal tendem a vender 40.12% a mais, na média, do que em dias regulares.

# %%
df_h7 = df4.groupby('state_holiday').agg({'sales': 'mean'}).reset_index()
df_h7_2 = df4.groupby(['year', 'state_holiday']).agg({'sales': 'mean'}).reset_index()

fig, ax = plt.subplots(1, 2)

sns.barplot(data=df_h7, x='state_holiday', y='sales', palette='mako', ax=ax[0])
for i in ax[0].containers:
    ax[0].bar_label(i,color='white', label_type= 'center', fontsize=18, fmt='%.2f')
    
ax[0].set_title('Average sales per State Holiday', fontsize=25)

sns.barplot(data=df_h7_2, x='year', y='sales', hue='state_holiday', palette='mako', ax=ax[1])
# adding bar's labels on top
for i in ax[1].containers:
    ax[1].bar_label(i, color='black', label_type= 'edge', fontsize=15, fmt='%.0f',rotation=0)
    
ax[1].set_title('Average sales per State Holiday and Year', fontsize=25)

plt.show()

# %%
aux = df_h7.set_index('state_holiday')
print(f"Porcentagem de vendas a mais no feriado de Natal: {int((aux.loc['christmas'] / aux.loc['regular_day'] - 1) * 100)}%")
# Out:
# Porcentagem de vendas a mais no feriado de Natal: 40%

# %% [markdown]
# #### H8. Lojas deveriam vender mais ao longo dos anos.
# **VERDADEIRO** As lojas apresentaram um aumento médio no volume de vendas YoY (year over year) de 1.99%

# %%
df_h8 = df4.groupby('year').sales.mean().reset_index()
df_h8['YoY'] = df_h8['sales'].rolling(window=2).apply( lambda x: round((x.iloc[1] / x.iloc[0] -1) * 100,2) )

plt.figure()
plt.title('Mean Sales over Years', fontsize=25)
ax = sns.barplot(x='year',y='sales',data=df_h8, palette='mako')

for i in ax.containers:
    ax.bar_label(i,color='white',label_type='center')
    
plt.show()

# %%
YoY_mean = df_h8['YoY'].mean()

print(f'VERDADEIRO. Ao longo dos anos o crescimento médio das vendas é de {YoY_mean}%')
# Out:
# VERDADEIRO. Ao longo dos anos o crescimento médio das vendas é de 1.99%

# %% [markdown]
# #### H9. Lojas deveriam vender mais no segundo semestre do ano.
# **VERDADEIRO** As lojas apresentaram um aumento médio no volume de vendas no segundo semestre em comparação ao primeiro de 1.99%

# %%
df_h9 = df4.loc[:, ['month', 'sales']]
df_h9['semester'] = ((df4['month'] - 1) // 6) + 1
df_h9_1 = df_h9.groupby('semester').sales.mean().reset_index()
df_h9_2 = df4.groupby('month').sales.mean().reset_index()

fig, ax = plt.subplots(2, 1)

sns.barplot(data=df_h9_1, x='semester', y='sales', palette='mako', ax=ax[0])
for i in ax[0].containers:
    ax[0].bar_label(i, color='white', fontsize=20, label_type='center')
ax[0].set_title('Average sales per semester', fontsize=25)
ax[0].set_xticklabels(['First Semester', 'Second Semester'])

sns.barplot(data=df_h9_2, x='month', y='sales', palette='mako', ax=ax[1])
ax[1].axvline(x=5.5, linestyle='--', color='b')
ax[1].text(2, 8000, 'First Semester', fontsize = 15)
ax[1].text(8, 8000, 'Second Semester', fontsize = 15)

plt.show()

# %% [markdown]
# #### H10. Lojas deveriam vender mais depois do dia 10 de cada mês.
# **FALSO** Após o dia 10 de cada mês, as vendas são em média 7% menores. Além disso, nota-se que os picos de vendas estão após o dia 30 do mês e nos primeiros dias do seguinte.

# %%
df_h10 = df4.loc[:, ['day', 'sales']].groupby('day').sales.mean().reset_index()
df_h10_1 = df_h10.groupby(df_h10['day'] > 10).sales.mean().reset_index()

fig, ax = plt.subplots(1, 2)

sns.lineplot(data=df_h10, x='day', y='sales', ax=ax[0])
ax[0].set_title('Average sales per day', fontsize=25)
ax[0].axvline(x=10, linestyle='--', color='b')
ax[0].text(11, 8000, 'Day 10', color='b', fontsize = 15)

sns.barplot(data=df_h10_1, x='day', y='sales', palette='mako', ax=ax[1])
for i in ax[1].containers:
    ax[1].bar_label(i, color='white', fontsize=20, label_type='center')
ax[1].set_title('Average sales before and after day 10', fontsize=25)
ax[1].set_xticklabels(['before', 'after'])


plt.show()

# %% [markdown]
# #### H11. Lojas deveriam vender menos aos finais de semana.
# **VERDADEIRO** Lojas vendem cerca de 22,6% mais, na média, nos fins de semana do que em dias regulares da semana.

# %%
df_h11 = df4.loc[:, ['day_of_week', 'sales']].groupby('day_of_week').sales.mean().reset_index()
df_h11_1 = df_h11.groupby((df_h11['day_of_week'] == 1) | (df_h11['day_of_week'] == 7)).sales.mean().reset_index()

fig, ax = plt.subplots(1, 2)

sns.barplot(data=df_h11, x='day_of_week', y='sales', palette='mako', ax=ax[0])
for i in ax[0].containers:
    ax[0].bar_label(i, color='black', label_type= 'edge',fontsize=20,fmt='%.0f',rotation=0)
ax[0].set_title('Average sales per day of week', fontsize=25)
ax[0].set_xticklabels(['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday'])


sns.barplot(data=df_h11_1, x='day_of_week', y='sales', palette='mako', ax=ax[1])
for i in ax[1].containers:
    ax[1].bar_label(i, color='white', fontsize=20, label_type='center')
ax[1].set_title('Average sales by weekends and week days', fontsize=25)
ax[1].set_xticklabels(['Week Days', 'Weekend'])

plt.show()

# %% [markdown]
# #### H12. Lojas deveriam vender menos durante os feriados escolares.
# **VERDADEIRO** Lojas vendem cerca de % mais, na média, em dias de feriados escolares do que em outros dias.

# %%
df_h12 = df4.groupby('school_holiday').sales.mean().reset_index()

fig, ax = plt.subplots()

sns.barplot(data=df_h12, x='school_holiday', y='sales', palette='mako')
for i in ax.containers:
    ax.bar_label(i, color='white', fontsize=20, label_type='center')
ax.set_title('Average sales between other days and school holidays', fontsize=25)
ax.set_xticklabels(['Other Days', 'School Holidays'])

plt.show()

# %% [markdown]
# #### 4.2.1) Resumo das Hipóteses

# %%
tab =[['Hipoteses', 'Conclusao', 'Relevancia'],
      ['H1', 'VERDADEIRO', 'Alta'],  
      ['H2', 'FALSO', 'Baixa'],  
      ['H3', 'FALSO', 'Media'],
      ['H4', 'VERDADEIRO', 'Media'],
      ['H5', '-', '-'],
      ['H6', 'FALSO', 'Alta'],
      ['H7', 'VERDADEIRO', 'Alta'],
      ['H8', 'VERDADEIRO', 'Baixa'],
      ['H9', 'VERDADEIRO', 'Baixa'],
      ['H10', 'FALSO', 'Alta'],
      ['H11', 'VERDADEIRO', 'Alta'],
      ['H12', 'VERDADEIRO', 'Baixa'],
     ]  

print( tabulate( tab, headers='firstrow' ) )

# %% [markdown]
# ### 4.3) Análise Multivariada

# %% [markdown]
# #### 4.3.1) Variáveis Numéricas

# %%
correlation = num_attr.corr( method='pearson' )
sns.heatmap( correlation, cmap='mako', annot=True );

# %% [markdown]
# #### 4.3.2) Variáveis Categóricas

# %%
# only categorical data
a = df4.select_dtypes( include='object' )

# Calculate cramer V
a1 = cramer_v( a['state_holiday'], a['state_holiday'] )
a2 = cramer_v( a['state_holiday'], a['store_type'] )
a3 = cramer_v( a['state_holiday'], a['assortment'] )

a4 = cramer_v( a['store_type'], a['state_holiday'] )
a5 = cramer_v( a['store_type'], a['store_type'] )
a6 = cramer_v( a['store_type'], a['assortment'] )

a7 = cramer_v( a['assortment'], a['state_holiday'] )
a8 = cramer_v( a['assortment'], a['store_type'] )
a9 = cramer_v( a['assortment'], a['assortment'] )

# Final dataset
d = pd.DataFrame( {'state_holiday': [a1, a2, a3], 'store_type': [a4, a5, a6], 'assortment': [a7, a8, a9] })
d = d.set_index( d.columns )

sns.heatmap( d, cmap='mako', annot=True );

# %% [markdown]
# # 5.0) Preparação dos Dados

# %%
df5 = df4.copy()

# %% [markdown]
# ### 5.1) Normalização

# %%
# Não há variáveis independentes com a distribuição normal no conjunto de dados

# %% [markdown]
# ### 5.2) Rescaling

# %%
mms = MinMaxScaler()
rs = RobustScaler()

# competition_distance -> RobustScaler
df5['competition_distance'] = rs.fit_transform(df5[['competition_distance']].values)
pickle.dump(rs, open('api/parameter/competition_distance_scaler.pkl', 'wb'))

# competition_open_since -> RobustScaler
df5['competition_open_since'] = rs.fit_transform(df5[['competition_open_since']].values)
pickle.dump(rs, open('api/parameter/competition_open_since_scaler.pkl', 'wb'))

# competition_duration -> RobustScaler
df5['competition_duration'] = rs.fit_transform(df5[['competition_duration']].values)
pickle.dump(rs, open('api/parameter/competition_duration_scaler.pkl', 'wb'))

# promo2_since -> MinMaxScaler
df5['promo2_since'] = mms.fit_transform(df5[['promo2_since']].values)
pickle.dump(mms, open('api/parameter/promo2_since_scaler.pkl', 'wb'))

# promo_time_week -> MinMaxScaler
df5['promo_time_week'] = mms.fit_transform(df5[['promo_time_week']].values)
pickle.dump(mms, open('api/parameter/promo_time_week_scaler.pkl', 'wb'))

# week_of_year -> MinMaxScaler
df5['week_of_year'] = mms.fit_transform(df5[['week_of_year']].values)
pickle.dump(mms, open('api/parameter/week_of_year_scaler.pkl', 'wb'))

# %% [markdown]
# ### 5.3) Transformações

# %% [markdown]
# #### 5.3.1) Encoding

# %%
ohe = OneHotEncoder()
le = LabelEncoder()
oe = OrdinalEncoder()

# promo, school_holiday, promo2, is_promo -> OneHot
df5 = pd.get_dummies( df5, prefix=['state_holiday'], columns=['state_holiday'] )

# store_type -> Label *
df5['store_type'] = le.fit_transform(df5['store_type'])
pickle.dump(le, open('api/parameter/store_type_encoder.pkl', 'wb'))

# assortment - Ordinal Encoding
assortment_dict = {'basic': 1,  'extra': 2, 'extended': 3}
df5['assortment'] = df5['assortment'].map( assortment_dict )

# %% [markdown]
# #### 5.3.2) Transformação da variável Target

# %%
df5['sales'] = np.log1p(df5['sales'])

# %% [markdown]
# #### 5.3.3) Transformação de Natureza

# %%
# day of week
df5['day_of_week_sin'] = df5['day_of_week'].apply( lambda x: np.sin( x * ( 2. * np.pi/7 ) ) )
df5['day_of_week_cos'] = df5['day_of_week'].apply( lambda x: np.cos( x * ( 2. * np.pi/7 ) ) )

# month
df5['month_sin'] = df5['month'].apply( lambda x: np.sin( x * ( 2. * np.pi/12 ) ) )
df5['month_cos'] = df5['month'].apply( lambda x: np.cos( x * ( 2. * np.pi/12 ) ) )

# day 
df5['day_sin'] = df5['day'].apply( lambda x: np.sin( x * ( 2. * np.pi/30 ) ) )
df5['day_cos'] = df5['day'].apply( lambda x: np.cos( x * ( 2. * np.pi/30 ) ) )

# week of year
df5['week_of_year_sin'] = df5['week_of_year'].apply( lambda x: np.sin( x * ( 2. * np.pi/52 ) ) )
df5['week_of_year_cos'] = df5['week_of_year'].apply( lambda x: np.cos( x * ( 2. * np.pi/52 ) ) )

# %% [markdown]
# # 6) Seleção de Features

# %%
df6 = df5.copy()

# %%
cols_drop = ['week_of_year', 'day', 'month', 'day_of_week', 'promo2_since', 'competition_open_since', 'year_week' ]
df6 = df6.drop( cols_drop, axis=1 )

# %% [markdown]
# ### 6.1) Split dos dados em treino e teste

# %%
# dados de treino
X_train = df6.loc[df6['date'] < '2015-06-19', :]
y_train = df6.loc[df6['date'] < '2015-06-19', 'sales']

# dados de teste
X_test = df6.loc[df6['date'] >= '2015-06-19', :]
y_test = df6.loc[df6['date'] >= '2015-06-19', 'sales']

print(f"Train Min Date: {X_train.date.min()}")
print(f"Train Max Date: {X_train.date.max()}")

print(f"\nTest Min Date: {X_test.date.min()}")
print(f"Test Min Date: {X_test.date.max()}")
# Out:
# Train Min Date: 2013-01-01 00:00:00
# Train Max Date: 2015-06-18 00:00:00
#
# Test Min Date: 2015-06-19 00:00:00
# Test Min Date: 2015-07-31 00:00:00

# %% [markdown]
# ### 6.2) Seleção de features com Boruta

# %%
## This process is executed onlly once, it takes too long and its resullt is 
## stored in the 'cols_selected_boruta' variable.

# # train and test dataset for boruta
# x_train_np = X_train.drop(columns=['date', 'sales']).values
# y_train_np = y_train.values.ravl()

# # defining estimator -> RandomForestRegressor
# rf = RandomForestRegressor(n_jobs=-1)

# # running boruta process
# boruta = BorutaPy(rf, n_estimators='auto', verbose=2, random_state=42).fit(x_train_np, y_train_np)

# %% [markdown]
# #### 6.2.1) Melhores features selecionadas pelo Boruta

# %%
## This process is executed onlly once, it takes too long and its resullt is 
## stored in the 'cols_selected_boruta' variable.

# cols_selected = boruta.support_.tolist()

# # best features
# X_train_fs = X_train.drop(columns=['date', 'sales'])
# cols_selected_boruta = X_train_fs.iloc[:, cols_selected].columns.to_list()

# # not selected boruta
# cols_not_selected_boruta = list(np.setdiff1d( X_train_fs.columns, cols_selected_boruta ))

# %% [markdown]
# ### 6.3) Seleção de features manual

# %%
cols_selected_boruta = [
    'store',
    'promo',
    'store_type',
    'assortment',
    'competition_distance',
    'competition_open_since_month',
    'competition_open_since_year',
    'promo2',
    'promo2_since_week',
    'promo2_since_year',
    'competition_duration',
    'promo_time_week',
    'day_of_week_sin',
    'day_of_week_cos',
    'month_sin',
    'month_cos',
    'day_sin',
    'day_cos',
    'week_of_year_sin',
    'week_of_year_cos',
]

# columns to add
feat_to_add = ['date', 'sales']

cols_selected_boruta_full = cols_selected_boruta.copy()
cols_selected_boruta_full.extend( feat_to_add )

# %% [markdown]
# # 7) Treinamento de algoritmos de ML

# %%
df7 = df6.copy()

# %%
x_train = X_train[cols_selected_boruta]
x_test = X_test[cols_selected_boruta]

# para o cross-validation
x_training = X_train[cols_selected_boruta_full]

# %% [markdown]
# ### 7.1) Modelo Baseline

# %%
aux1 = x_test.copy()
aux1['sales'] = y_test.copy()
aux2 = aux1.groupby('store').agg({'sales': 'mean'}).rename(columns={'sales': 'predictions'})
aux2 = aux1.merge(aux2, how='left', left_on='store', right_index=True)

baseline_results = ml_error('Average Model', np.expm1(y_test), np.expm1(aux2['predictions']))
baseline_results
# Out:
#       Model Name     MAE  MAPE    RMSE
# 0  Average Model 1354.80  0.21 1835.14

# %% [markdown]
# ### 7.2) Linear Models

# %% [markdown]
# #### 7.2.1) Regressão Linear

# %%
lr = LinearRegression().fit(x_train, y_train)

# prediction
yhat_lr = lr.predict(x_test)

# results
lr_results = ml_error('Linear Regression', np.expm1(y_test), np.expm1(yhat_lr))
lr_results
# Out:
#           Model Name     MAE  MAPE    RMSE
# 0  Linear Regression 1870.53  0.29 2669.75

# %% [markdown]
# **Cross-Validation**

# %%
lr_results_cv = cross_validation(x_training, 'Linear Regerssion - CV', lr, 5, verbose=True)
lr_results_cv
# Out:
#                Model Name                 MAE           MAPE  \
# 0  Linear Regerssion - CV  2032.90 +/- 247.14  0.30 +/- 0.01
#
#                  RMSE
# 0  2885.37 +/- 348.96

# %% [markdown]
# #### 7.2.2) Regressão Lasso

# %%
lss = Lasso(alpha=10).fit(x_train, y_train)

# prediction
yhat_lss = lss.predict(x_test)

# results
lss_results = ml_error('Lasso Regression', np.expm1(y_test), np.expm1(yhat_lss))
lss_results
# Out:
#          Model Name     MAE  MAPE    RMSE
# 0  Lasso Regression 2198.58  0.34 3110.51

# %% [markdown]
# **Cross-Validation**

# %%
lss_results_cv = cross_validation(x_training, 'Lasso Regressionn - CV', lss, 5)
lss_results_cv
# Out:
#                Model Name                 MAE           MAPE  \
# 0  Lasso Regressionn - CV  2388.68 +/- 398.48  0.34 +/- 0.01
#
#                  RMSE
# 0  3369.37 +/- 567.55

# %% [markdown]
# ### 7.3) Random Forest Regressor

# %%
rf = RandomForestRegressor(n_estimators=100, n_jobs=-1, random_state=42).fit(x_train, y_train)

# prediction
yhat_rf = rf.predict(x_test)

# results
rf_results = ml_error('Random Forest Regressor', np.expm1(y_test), np.expm1(yhat_rf))
rf_results
# Out:
#                 Model Name    MAE  MAPE    RMSE
# 0  Random Forest Regressor 685.94  0.10 1021.96

# %% [markdown]
# **Cross-Validation**

# %%
# results_rf_cv = cross_validation(x_training, 'Random Forest Regressor - CV', rf, 5)
# results_rf_cv

# %% [markdown]
# ### 7.4) XGBoost Regressor

# %%
# model
model_xgb = xgb.XGBRegressor(
    objective='reg:squarederror',
    n_estimators=100,
    eta=0.01,
    max_depth=10,
    subsample=0.7, 
    colsample_bytree=0.9
).fit(x_train, y_train)

# prediction
yhat_xgb = model_xgb.predict(x_test)

# results
xgb_results = ml_error('XGBoost Regressor', np.expm1(y_test), np.expm1(yhat_xgb))
xgb_results
# Out:
#           Model Name     MAE  MAPE    RMSE
# 0  XGBoost Regressor 6683.30  0.95 7330.58

# %% [markdown]
# **Cross-Validation**

# %%
# xgb_results_cv = cross_validation(x_training, 5, 'XGBoost Regression - CV', model_xgb, verbose=False)
# xgb_results_cv

# %% [markdown]
# ### 7.5) Compare Models Performance

# %% [markdown]
# #### 7.6.1) Single Performance

# %%
modelling_result = pd.concat( [baseline_results, lr_results, lss_results, rf_results, xgb_results] )
modelling_result.sort_values( 'RMSE' )
# Out:
#                 Model Name     MAE  MAPE    RMSE
# 0  Random Forest Regressor  685.94  0.10 1021.96
# 0            Average Model 1354.80  0.21 1835.14
# 0        Linear Regression 1870.53  0.29 2669.75
# 0         Lasso Regression 2198.58  0.34 3110.51
# 0        XGBoost Regressor 6683.30  0.95 7330.58

# %% [markdown]
# #### 7.6.2) Real Performance - Cross Validation

# %%
#modelling_result_cv = pd.concat( [lr_result_cv, lrr_result_cv, rf_result_cv, xgb_result_cv] )
modelling_result_cv = pd.concat( [lr_results_cv, lss_results_cv] )
modelling_result_cv
# Out:
#                Model Name                 MAE           MAPE  \
# 0  Linear Regerssion - CV  2032.90 +/- 247.14  0.30 +/- 0.01
# 0  Lasso Regressionn - CV  2388.68 +/- 398.48  0.34 +/- 0.01
#
#                  RMSE
# 0  2885.37 +/- 348.96
# 0  3369.37 +/- 567.55

# %% [markdown]
# # 8.0) Hyper-parameter Fine Tuning

# %%
# df8 = df7.copy()

# %% [markdown]
# ### 8.1) Random Search

# %%
# params = {
#     'n_estimators': [1500, 1700, 2500, 3000, 3500],
#     'eta': [0.01, 0.03],
#     'max_depth': [3, 5, 9],
#     'subsample': [0.1, 0.5, 0.7],
#     'colsample_bytree': [0.3, 0.7, 0.9],
#     'min_child_weight': [3, 8, 15]
# }

# MAX_ITER = 5

# %%
# random_search_results = pd.DataFrame()

# for i in range(MAX_ITER):
#     # choose values for parameters randomly
#     cr_params = { k: random.sample(v, 1)[0] for k, v in params.items()}
#     print(cr_params)
    
#     # model
#     model_tuned = xgb.XGBRegressor(
#         objective='reg:squarederror',
#         n_estimators=cr_params['n_estimators'],
#         eta=cr_params['eta'],
#         max_depth=cr_params['max_depth'],
#         subsample=cr_params['subsample'],
#         colsample_bytree=cr_params['colsample_bytree']
#     ).fit(x_train, y_train)
                   
#     # performance
#     result_random_search_cv = cross_validation(x_training, 2, 'XGBoost Regressor', model_tuned, verbose=False)
    
#     random_search_results = pd.concat([random_search_results, result_random_search_cv], axis=0)
                   
# random_search_results

# %% [markdown]
# ### 8.2) Final Model

# %%
# tuned parameters
tuned_params = {
    'n_estimators': 3000,
    'eta': 0.03,
    'max_depth': 5,
    'subsample': 0.7,
    'colsample_bytree': 0.7,
    'min_child_weight': 3
}

# %%
# model
final_model_tuned = xgb.XGBRegressor(
    objective='reg:squarederror',
    n_estimators=tuned_params['n_estimators'],
    eta=tuned_params['eta'],
    max_depth=tuned_params['max_depth'],
    subsample=tuned_params['subsample'],
    colsample_bytree=tuned_params['colsample_bytree']
).fit(x_train, y_train)

# prediction
yhat_xgb_tuned = final_model_tuned.predict( x_test )

# performance
final_result_tuned = ml_error( 'XGBoost Regressor', np.expm1( y_test ), np.expm1(yhat_xgb_tuned))
final_result_tuned
# Out:
#           Model Name    MAE  MAPE    RMSE
# 0  XGBoost Regressor 765.05  0.12 1098.34

# %%
# tendencia do modelo em supervalorizar (valor positivo) ou subvalorizar (valor negativo), em média,
# o valor das previsões.
mpe = mean_percentage_error( np.expm1( y_test ), np.expm1( yhat_xgb_tuned ) )
mpe
# Out:
# -0.01914051212091045

# %% [markdown]
# # 9.0) TRADUCAO E INTERPRETACAO DO ERRO

# %%
df9 = X_test[cols_selected_boruta_full]

# rescale back
df9['sales'] = np.expm1(df9['sales'])
df9['predictions'] = np.expm1(yhat_xgb_tuned)

# %% [markdown]
# ### 9.1) Business Performance

# %%
df9_1 = df9[['store', 'predictions', 'sales']].groupby('store').agg({'predictions': 'sum', 'sales': 'sum'}).reset_index()

# Errors
df9_1['MAE'] = df9[['store', 'sales', 'predictions']].groupby('store').apply(lambda x: mean_absolute_error(x['sales'], x['predictions']))
df9_1['MAPE'] = df9[['store', 'sales', 'predictions']].groupby('store').apply(lambda x: mean_absolute_percentage_error(x['sales'], x['predictions']))

# Scenarios
df9_1['worst_scenario'] = df9_1['predictions'] - df9_1['MAE']
df9_1['best_scenario'] = df9_1['predictions'] + df9_1['MAE']

# Order
df9_1 = df9_1[['store', 'predictions', 'worst_scenario', 'best_scenario', 'MAE', 'MAPE']]

# %%
df9_1.sample(5)
# Out:
#      store  predictions  worst_scenario  best_scenario     MAE  MAPE
# 558    559    216775.78       216446.16      217105.40  329.62  0.10
# 153    154    322837.19       321830.38      323844.00 1006.81  0.17
# 156    157    350317.22       349552.97      351081.47  764.25  0.15
# 211    212    186564.05       184947.14      188180.95 1616.91  0.11
# 392    393    232725.20       231971.22      233479.19  753.99  0.11

# %%
plt.figure()

sns.scatterplot(x='store', y='MAPE', data=df9_1)

plt.show()

# %%
df9_1.sort_values(by='MAPE', ascending=False).head()
# Out:
#      store  predictions  worst_scenario  best_scenario     MAE  MAPE
# 292    293    232694.20       229276.33      236112.08 3417.88  0.61
# 909    910    235696.59       227635.91      243757.28 8060.68  0.53
# 286    287    309694.06       308754.56      310633.57  939.51  0.35
# 876    877    244026.17       239950.95      248101.39 4075.22  0.34
# 170    171    296683.69       295376.47      297990.90 1307.22  0.33

# %% [markdown]
# ### 9.2) Total Performance

# %%
df9_1[['predictions', 'worst_scenario', 'best_scenario']].sum(axis=0).map(lambda x: f'${x:,.2f}')\
    .reset_index().rename(columns={'index': 'Scenario', 0: 'Total'})
# Out:
#          Scenario            Total
# 0     predictions  $286,828,352.00
# 1  worst_scenario  $285,804,949.65
# 2   best_scenario  $287,516,602.94

# %% [markdown]
# ### 9.3) Machine Learning Performance

# %%
df9['error'] = df9['sales'] - df9['predictions']
df9['error_rate'] = df9['predictions'] / df9['sales']

# %%
plt.subplot(2, 2, 1)

sns.lineplot(x='date', y='sales', data=df9, label='sales')
sns.lineplot(x='date', y='predictions', data=df9, label='prediction')

plt.subplot(2, 2, 2)

sns.lineplot(x='date', y='error_rate', data=df9)
plt.axhline(y=1, color='b', linestyle='--')

plt.subplot(2, 2, 3)

sns.distplot(df9['error'])

plt.subplot(2, 2, 4)

sns.scatterplot(x='predictions', y='error', data=df9)

plt.show()

# %% [markdown]
# # 10) Deploy do modelo em Produção

# %%
pwd = os.getcwd()

# Save Trained Model
pickle.dump( final_model_tuned, open( f'{pwd}/api/model/model_rossmann.pkl', 'wb' ) )

# %% [markdown]
# ### 10.1) Rosmann Class

# %% [markdown]
# The code for this cell is in -> `api/rossmann/Rossmann.py`

# %% [markdown]
# ### 10.2) API Handler

# %% [markdown]
# The code for this cell is in -> **`api/handler.py`**

# %% [markdown]
# ### 10.3) API Tester

# %%
df_test_raw = pd.read_csv('data/test.csv')
df_store_raw = pd.read_csv('data/store.csv')

# merge test + store datasets
df_test = df_test_raw.merge(df_store_raw, how='left', on='Store')

# %%
# choose store for prediction
df_test = df_test.loc[df_test['Store'].isin([12, 22, 24]), :]

# remove closed days
df_test = df_test[df_test['Open'] != 0]
df_test = df_test[~df_test['Open'].isna()]
df_test = df_test.drop(columns='Id')

# %%
# convert dataframe to JSON
data = json.dumps(df_test.to_dict(orient='records'))

# %%
# API Call
# url = 'http://127.0.0.1:5000/rossmann/predict'
url = 'https://rossmann-sales-forecast.onrender.com/rossmann/predict'
header = {'Content-type': 'application/json'}
data = data

r = requests.post(url, data=data, headers=header)
print(f'Status Code {r.status_code}')
# Out:
# Status Code 200

# %%
d1 = pd.DataFrame(r.json(), columns=r.json()[0].keys())

# %%
d1.head()
# Out:
#    store  day_of_week                      date  open  promo state_holiday  \
# 0     12            4  2015-09-17T00:00:00.000Z  1.00      1   regular_day
# 1     22            4  2015-09-17T00:00:00.000Z  1.00      1   regular_day
# 2     24            4  2015-09-17T00:00:00.000Z  1.00      1   regular_day
# 3     12            3  2015-09-16T00:00:00.000Z  1.00      1   regular_day
# 4     22            3  2015-09-16T00:00:00.000Z  1.00      1   regular_day
#
#    school_holiday store_type assortment  competition_distance  \
# 0               0          a   extended               1070.00
# 1               0          a      basic               1040.00
# 2               0          a   extended               4590.00
# 3               0          a   extended               1070.00
# 4               0          a      basic               1040.00
#
#    competition_open_since_month  competition_open_since_year  promo2  \
# ...

# %%
d2 = d1[['store', 'prediction']].groupby('store').sum().reset_index()

for i in range(len(d2)):
    print(f"Store Number {d2.loc[i, 'store']} will sell ${d2.loc[i, 'prediction']} in the next 6 weeks")
# Out:
# Store Number 12 will sell $275711.8886718748 in the next 6 weeks
# Store Number 22 will sell $170652.9143066404 in the next 6 weeks
# Store Number 24 will sell $338928.4047851564 in the next 6 weeks
